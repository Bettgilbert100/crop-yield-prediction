# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
mpl.style.use('ggplot')

# %%
crop=pd.read_csv('new data.csv')

# %%
crop.head()
# Out:
#     county sub county   item       season     yield
# 0  MOMBASA  CHANGAMWE  Maize   Long Rains  1.214774
# 1  MOMBASA      JOMVU  Maize   Long Rains  1.862348
# 2  MOMBASA    KISAUNI  Maize  Short Rains  3.334722
# 3  MOMBASA     LIKONI  Maize  Short Rains  2.419293
# 4  MOMBASA      MVITA  Maize   Long Rains  1.117336

# %%
crop.shape
# Out:
# (4715, 5)

# %%
crop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4715 entries, 0 to 4714
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   county      4715 non-null   object
#  1   sub county  4715 non-null   object
#  2   item        4715 non-null   object
#  3   season      4715 non-null   object
#  4   yield       4715 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 184.3+ KB

# %%
backup=crop.copy()

# %% [markdown]
# # cleaning data

# %% [markdown]
# # removing empty spaces
# # removing non string in string columns
# # removing strings in integer columns

# %%
crop['yield']=crop['yield'].astype(float)

# %%
crop['county']=crop['county'].str.replace(',','').astype(object)

# %%
crop['item']=crop['item'].str.replace('_','').astype(object)

# %%
crop['county']=crop['county'].str.replace('/','').astype(object)

# %%
crop=crop.reset_index(drop=True)

# %%
crop
# Out:
#        county  sub county    item       season     yield
# 0     MOMBASA   CHANGAMWE   Maize   Long Rains  1.214774
# 1     MOMBASA       JOMVU   Maize   Long Rains  1.862348
# 2     MOMBASA     KISAUNI   Maize  Short Rains  3.334722
# 3     MOMBASA      LIKONI   Maize  Short Rains  2.419293
# 4     MOMBASA       MVITA   Maize   Long Rains  1.117336
# ...       ...         ...     ...          ...       ...
# 4710    BUSIA      BUTULA  Cotton  Short Rains  0.137166
# 4711    BUSIA     NAMBALE  Cotton  Short Rains  0.266464
# 4712    BUSIA       SAMIA  Cotton  Short Rains  0.639140
# 4713    BUSIA  TESO NORTH  Cotton  Short Rains  0.897353
# 4714    BUSIA  TESO SOUTH  Cotton  Short Rains  0.486365
#
# [4715 rows x 5 columns]

# %%
crop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4715 entries, 0 to 4714
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   county      4715 non-null   object
#  1   sub county  4715 non-null   object
#  2   item        4715 non-null   object
#  3   season      4715 non-null   object
#  4   yield       4715 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 184.3+ KB

# %%
crop.describe(include='all')
# Out:
#        county        sub county   item      season        yield
# count    4715              4715   4715        4715  4715.000000
# unique     46               339     19           2          NaN
# top     KITUI  MT. KENYA FOREST  Maize  Long Rains          NaN
# freq      270                33    344        2374          NaN
# mean      NaN               NaN    NaN         NaN     2.935080
# std       NaN               NaN    NaN         NaN     4.945787
# min       NaN               NaN    NaN         NaN     0.111480
# 25%       NaN               NaN    NaN         NaN     0.392224
# 50%       NaN               NaN    NaN         NaN     0.894168
# 75%       NaN               NaN    NaN         NaN     2.852346
# max       NaN               NaN    NaN         NaN    48.215111

# %%
crop['county'].unique()
# Out:
# array(['MOMBASA', 'KWALE', 'KILIFI', 'TANA RIVER', 'LAMU', 'GARISSA',
#        'WAJIR', 'MANDERA', 'MARSABIT', 'SOLOLO', 'MERU', 'THARAKA  NITHI',
#        'EMBU', 'KITUI', 'MACHAKOS', 'MAKUENI', 'NYANDARUA', 'NYERI',
#        'KIRINYAGA', 'KIAMBU', 'TURKANA', 'WEST POKOT', 'SAMBURU',
#        'TRANS NZOIA', 'UASIN GISHU', 'ELGEYO MARAKWET', 'NANDI',
#        'BARINGO', 'LAIKIPIA', 'NAKURU', 'NAROK', 'KAJIADO', 'KERICHO',
#        'BOMET', 'KAKAMEGA', 'VIHIGA', 'BUNGOMA', 'BUSIA', 'SIAYA',
#        'KISUMU', 'HOMA BAY', 'MIGORI', 'KISII', 'NYAMIRA', 'NAIROBI',
#        'MANDERA WEST'], dtype=object)

# %%
crop['sub county'].unique()
# Out:
# array(['CHANGAMWE', 'JOMVU', 'KISAUNI', 'LIKONI', 'MVITA', 'NYALI',
#        'KINANGO', 'LUNGALUNGA', 'MATUGA', 'MSAMBWENI', 'SAMBURU',
#        'CHONYI', 'GANZE', 'KALOLENI', 'KAUMA', 'KILIFI NORTH',
#        'KILIFI SOUTH', 'MAGARINI', 'MALINDI', 'RABAI', 'TANA DELTA',
#        'TANA NORTH', 'TANA RIVER', 'LAMU EAST', 'LAMU WEST',
#        'TAITA TAVETA', 'MWATATE', 'TAITA', 'TAVETA', 'VOI', 'BALAMBALA',
#        'DADAAB', 'FAFI', 'GARISSA', 'HULUGHO', 'IJARA', 'LAGDERA', 'BUNA',
#        'ELDAS', 'HABASWEIN', 'TARBAJ', 'WAJIR EAST', 'WAJIR NORTH',
#        'WAJIR SOUTH', 'WAJIR WEST', 'BANISA', 'KOTULO', 'LAFEY',
#        'MANDERA CENTRAL', 'MANDERA EAST', 'MANDERA NORTH', 'LOIYANGALANI',
#        'MARSABIT CENTRAL', 'MARSABIT NORTH', 'MARSABIT SOUTH', 'MOYALE',
#        'NORTH HORR', 'ISIOLO', 'GARBATULLA', 'MERTI', 'BUURI EAST',
#        'BUURI WEST', 'IGEMBE CENTRAL', 'IGEMBE NORTH', 'IGEMBE SOUTH',
#        'IMENTI NORTH', 'IMENTI SOUTH', 'MERU CENTRAL', 'TIGANIA CENTRAL',
# ...

# %%
crop['item'].unique()
# Out:
# array(['Maize', 'Sorghum', 'Rice', 'Potatoes', 'Beans', 'Cassava',
#        'Sweet Potatoes', 'Wheat', 'Green grams', 'Bananas', 'Cabbages',
#        'Tomatoes', 'Onions', 'Ground Nuts', 'Millet', 'Watermelons',
#        'Kales', 'Sugarcane', 'Cotton'], dtype=object)

# %%
crop['season'].unique()
# Out:
# array(['Long Rains', 'Short Rains'], dtype=object)

# %%
import seaborn as sns

# %%
plt.subplots(figsize=(15,7))
ax=sns.boxplot(x='county',y='yield',data=crop)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()

# %%
plt.subplots(figsize=(20,10))
ax=sns.swarmplot(x='item',y='yield',data=crop)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()
# Out:
# C:\Users\Gilbert\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 25.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Gilbert\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 58.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Gilbert\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 57.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Gilbert\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 48.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.relplot(x='season',y='yield',data=crop,height=7,aspect=1.5)

# %%
plt.subplots(figsize=(14,7))
sns.boxplot(x='sub county',y='yield',data=crop)
# Out:
# <AxesSubplot:xlabel='sub county', ylabel='yield'>

# %%
ax=sns.relplot(x='county',y='yield',data=crop,hue='season',size='item',height=7,aspect=2)
ax.set_xticklabels(rotation=40,ha='right')

# %%
x=crop[['county','sub county','item','season']]
y=crop['yield']

# %%
x
# Out:
#        county  sub county    item       season
# 0     MOMBASA   CHANGAMWE   Maize   Long Rains
# 1     MOMBASA       JOMVU   Maize   Long Rains
# 2     MOMBASA     KISAUNI   Maize  Short Rains
# 3     MOMBASA      LIKONI   Maize  Short Rains
# 4     MOMBASA       MVITA   Maize   Long Rains
# ...       ...         ...     ...          ...
# 4710    BUSIA      BUTULA  Cotton  Short Rains
# 4711    BUSIA     NAMBALE  Cotton  Short Rains
# 4712    BUSIA       SAMIA  Cotton  Short Rains
# 4713    BUSIA  TESO NORTH  Cotton  Short Rains
# 4714    BUSIA  TESO SOUTH  Cotton  Short Rains
#
# [4715 rows x 4 columns]

# %%
y.shape
# Out:
# (4715,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %% [markdown]
# # create conehotencoder containing all categorie

# %%
ohe=OneHotEncoder()
ohe.fit(x[['county','sub county','item','season']])
# Out:
# OneHotEncoder()

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['county','sub county','item','season']),
                                    remainder='passthrough')

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6064\942627387.py in <module>
# ----> 1 pipe.fit(x_train,y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     388         """
#     389         fit_params_steps = self._check_fit_params(**fit_params)
# --> 390         Xt = self._fit(X, y, **fit_params_steps)
#     391         with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     392             if self._final_estimator != "passthrough":
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in _fit(self, X, y, **fit_params_steps)
#     346                 cloned_transformer = clone(transformer)
#     347             # Fit or load from cache the current transformer
# --> 348             X, fitted_transformer = fit_transform_one_cached(
# ...

# %%
y_pred=pipe.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.3349733183104392
